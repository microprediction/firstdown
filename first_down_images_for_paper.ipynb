# %% [markdown]
# <a href="https://colab.research.google.com/github/microprediction/firstdown/blob/main/first_down_images_for_paper.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
df = pd.read_csv('https://raw.githubusercontent.com/microprediction/nflMarkov/master/inputData/pbp_nfldb_2009_2013.csv')
import matplotlib.pyplot as plt

font = {'family' : 'normal',
        'weight' : 'normal',
        'size'   : 18}
import matplotlib
matplotlib.rc('font', **font)

# %% [markdown]
# # Images for paper

# %%
gains_on_first = df.loc[(df['dwn']==1)& (df['ytg']==10) & (df['type']=='RUSH') & (df['yds']<15) & (df['yds']>5),:]
gains_on_first[['yds']].rename(columns={'yds':'First Down Yards Gained'}).hist(bins=50)
import matplotlib.pyplot as plt
plt.ylabel('Count',fontsize=25)
plt.xlabel('Yards on first down',fontsize=25)
plt.title('First and ten rushing',fontsize=30)
# Out:
# Text(0.5, 1.0, 'First and ten rushing')
# findfont: Font family ['normal'] not found. Falling back to DejaVu Sans.

# %%
gains_on_first = df.loc[(df['dwn']==1)& (df['ytg']==5) & (df['type']=='PASS') & (df['yds']<8) & (df['yds']>1),:]
gains_on_first[['yds']].rename(columns={'yds':'First Down Yards Gained'}).hist(bins=50)
import matplotlib.pyplot as plt
plt.ylabel('Count',fontsize=25)
plt.xlabel('Yards on first down',fontsize=25)
plt.title('First and five passing',fontsize=30)
# Out:
# Text(0.5, 1.0, 'First and five passing')

# %%
gains_on_first = df.loc[(df['dwn']==2)& (df['ytg']==5) & (df['type']=='PASS') & (df['yds']<8) & (df['yds']>1),:]
gains_on_first[['yds']].rename(columns={'yds':'First Down Yards Gained'}).hist(bins=50)
import matplotlib.pyplot as plt
plt.ylabel('Count',fontsize=25)
plt.xlabel('Yards on first down',fontsize=25)
plt.title('First and five passing',fontsize=30)
# Out:
# Text(0.5, 1.0, 'First and five passing')

# %%
df['got_4'] = df['yds']>=4 
and_four = df.loc[(df['dwn']<=2)& (df['ytg']==4) & (df['yfog']<50),:]
and_four['got_4'].mean()
# Out:
# 0.46536523929471035

# %%
465/419
# Out:
# 1.1097852028639619
